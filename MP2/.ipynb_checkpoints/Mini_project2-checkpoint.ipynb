# %% [markdown]
# # Mini_Project 2
# ## Taks 0

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.mixture import GaussianMixture
from scipy import stats

import seaborn as sns
# %matplotlib notebook
sns.set_style('whitegrid')

# %%
baseline_csv = pd.read_csv("498DS_BaselineData.csv")
metformin_csv = pd.read_csv("498DS_MetforminData.csv")

# %%
print(len(baseline_csv.columns))
print(len(metformin_csv.columns))
#     Baseline cells: s_85_M2_N704_S502_RPKM, s_85_M2_N704_S504_RPKM and s_85_M2_N711_S507_RPKM
# ·         Metformin cells: s_204_M2_N704_S503_RPKM, s_204_M2_N711_S502_RPKM and s_63_M2_N702_S502_RPKM
# ·         Gene: TXNRD1
# Out:
# 174
# 182

# %%
metformin_csv[metformin_csv['GeneID'] == 'TXNRD1']
baseline_csv[baseline_csv['GeneID'] == 'TXNRD1']
# Out:
#        Chr  GeneID  StartCoding       Stop  CodingLength  \
# 754  chr12  TXNRD1    104609559  104744062          4233
#
#      s_62_M2_N701_S502_RPKM  s_62_M2_N701_S503_RPKM  s_62_M2_N701_S504_RPKM  \
# 754              160.147832                     0.0              129.160314
#
#      s_62_M2_N701_S505_RPKM  s_62_M2_N701_S506_RPKM           ...            \
# 754              126.879342               57.828562           ...
#
#      s_85_M2_N711_S501_RPKM  s_85_M2_N711_S502_RPKM  s_85_M2_N711_S503_RPKM  \
# 754               97.496592                     0.0              168.027198
#
#      s_85_M2_N711_S504_RPKM  s_85_M2_N711_S506_RPKM  s_85_M2_N711_S507_RPKM  \
# 754               57.838335              113.881628                54.60663
#
#      s_85_M2_N711_S508_RPKM  s_85_M2_N712_S503_RPKM  s_85_M2_N712_S504_RPKM  \
# 754              160.100423               82.398247               97.580781
#
#      s_85_M2_N712_S505_RPKM
# 754               61.414455
#
# [1 rows x 174 columns]

# %% [markdown]
# ### Task 1.1 Import both datasets into Pandas.
#         How many gene samples are present in each dataset?
#         How many cells are present in each dataset?
#         How many genes are common in both datasets?

# %%
print("In base cell dataset, there are", len(baseline_csv), "gene samples in datatset")
print("In metformin dateset, there are",len(metformin_csv), "gene samples in datatset")
# Out:
# In base cell dataset, there are 1170 gene samples in datatset
# In metformin dateset, there are 1170 gene samples in datatset

# %%
baseline = baseline_csv.drop(['Chr','GeneID','StartCoding','Stop','CodingLength'], axis=1)
metformin= metformin_csv.drop(['Chr','GeneID','Stop','Start','CodingLength'], axis=1)
print("In base cell, there are", len(baseline.columns), " cells in datatset")
print("In metformin cell, there are",len(metformin.columns), "cells in datatset")
# Out:
# In base cell, there are 169  cells in datatset
# In metformin cell, there are 177 cells in datatset

# %%
met_list = list(metformin_csv['GeneID'])
base_list = list(baseline_csv['GeneID'])
common = list(set(met_list).intersection(base_list))
print("There are",len(common),"genes are common in both datasets")
# Out:
# There are 833 genes are common in both datasets

# %% [markdown]
# ### Task 1.2 Plot the variation of gene expression across different genes for your assigned cells. You will have two plots - One for baseline cells and another for Metformin cells.

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s502 = baseline_csv['s_85_M2_N704_S502_RPKM']
s502 = s502[(32 < s502) & (s502 < 2000)]
s502 = np.log(s502)
s504 = baseline_csv['s_85_M2_N704_S504_RPKM']
s504 = s504[(32 < s504) & (s504 < 2000)]
s504 = np.log(s504)
s507 = baseline_csv['s_85_M2_N711_S507_RPKM']
s507 = s507[(32 < s507) & (s507 < 2000)]
s507 = np.log(s507)

s704 = metformin_csv['s_204_M2_N704_S503_RPKM']
s704 = s704[(32 < s704) & (s704 < 2000)]
s704 = np.log(s704)
s711 = metformin_csv['s_204_M2_N711_S502_RPKM']
s711 = s711[(32 < s711) & (s711 < 2000)]
s711 = np.log(s711)
s702 = metformin_csv['s_63_M2_N702_S502_RPKM']
s702 = s702[(32 < s702) & (s702 < 2000)]
s702 = np.log(s702)

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.distplot(s504, ax=ax,color="red",label = "s_85_M2_N704_S504_RPKM",hist=False);
sns.distplot(s507, ax=ax,color="yellow",label = "s_85_M2_N711_S507_RPKM",hist=False);
sns.distplot(s502, ax=ax,color="blue",label = "s_85_M2_N704_S502_RPKM",hist=False);
ax.legend()
ax.set_title('Variation of gene expression from basecell cells')
ax.set_ylabel('pdf')
ax.set_xlabel('(log) gene expression')
plt.show()

# %%
from numpy import linalg as LA
f, ax = plt.subplots(figsize=(10,10))

sns.distplot(s704, ax=ax,color="red",label = "s_204_M2_N704_S503_RPKM",hist=False);
sns.distplot(s711, ax=ax,color="blue",label = "s_204_M2_N711_S502_RPKM",hist=False);
sns.distplot(s702, ax=ax,color="yellow",label = "s_63_M2_N702_S502_RPKM",hist=False);
ax.legend()
ax.set_title('Variation of gene expression from metformin cells')
ax.set_ylabel('pdf')
ax.set_xlabel('(log) gene expression')
plt.show()

# %% [markdown]
# ### Task 1.3 Plot the variation of gene expression across different cells for your assigned gene.

# %%
bGene = baseline_csv[baseline_csv['GeneID'] == 'TXNRD1']
bGene = bGene.drop(['Chr','GeneID','StartCoding','Stop','CodingLength'], axis=1)
mGene = metformin_csv[metformin_csv['GeneID'] == 'TXNRD1']
mGene = mGene.drop(['Chr','GeneID','Stop','Start','CodingLength'], axis=1)

# %%
bGene=  bGene[(32 < bGene) & (bGene < 2000)]
b = (bGene.values.tolist())[0]
b = [x for x in b if str(x) != 'nan']
b = np.log(b)
mGene=  mGene[(32 < mGene) & (mGene < 2000)]
m = ((mGene.values).tolist())[0]
m = [x for x in m if str(x) != 'nan']
m = np.log(m)

# %%
f, ax = plt.subplots(figsize=(10, 10))

sns.distplot(m, ax=ax,color="red",label = "metformin",hist=False);
sns.distplot(b, ax=ax,color="blue",label = "baseline",hist=False);
ax.legend()
ax.set_title('Variation of gene expression from metformin cells')
ax.set_ylabel('pdf')
ax.set_xlabel('(log) gene expression')
plt.show()

# %% [markdown]
# ### Task 1.4 Perform the KS test on your Baseline and Metformin Variance distributions.
#     How many genes are differentially expressed at α=0.10,0.05,0.025,0.01,0.005

# %%
baselineT = baseline_csv.transpose()
metforminT = metformin_csv.transpose()
geneNames = set(baseline_csv['GeneID'].tolist()).intersection(set(metformin_csv['GeneID'].tolist()))
print("%d genes common in both dataset" % len(geneNames))
numDifferentlyExpressedGene = 0
candidateGenes = set()
Gene1 = 0
candidateGenes1 = set()
Gene2 = 0
candidateGenes2 = set()
Gene3 = 0
candidateGenes3 = set()
Gene4 = 0
candidateGenes4 = set()
Gene5 = 0
candidateGenes5 = set()
for selectGene in geneNames:
    bIndx = baselineT[1:2:].transpose()['GeneID'].tolist().index(selectGene)
    mIndx = metforminT[1:2:].transpose()['GeneID'].tolist().index(selectGene)
    bb = baselineT[bIndx].iloc[5:174].astype(float)
    mm = metforminT[mIndx].iloc[5:174].astype(float)    
    bb = bb[bb >=32]
    mm = mm[mm >= 32]
    b =np.log(bb)
    m = np.log(mm)
    Vars = {
        "Baseline": b,
        "Metformin": m
    }
    testResult = stats.ks_2samp(Vars['Baseline'], Vars["Metformin"])
    if testResult[1] < 0.1:
        candidateGenes.add(selectGene)
        numDifferentlyExpressedGene += 1
        print("%d: %s gene is differently expressed in baseline and metformin treated cells" % (numDifferentlyExpressedGene, selectGene))
        print("Test Statistics %f, %g" % (testResult[0], testResult[1]))
    if testResult[1] < 0.05:
        candidateGenes1.add(selectGene)
        Gene1 += 1
    if testResult[1] < 0.025:
        candidateGenes2.add(selectGene)
        Gene2 += 1
    if testResult[1] < 0.01:
        candidateGenes3.add(selectGene)
        Gene3 += 1
    if testResult[1] < 0.005:
        candidateGenes4.add(selectGene)
        Gene4 += 1
    if testResult[1] < 0.001:
        candidateGenes5.add(selectGene)
        Gene5 += 1
print(numDifferentlyExpressedGene," with alpha = 0.1")
print(Gene1," with alpha = 0.05")
print(Gene2," with alpha = 0.025")
print(Gene3," with alpha = 0.01")
print(Gene4," with alpha = 0.005")
print(Gene5," with alpha = 0.001")
# Out:
# 833 genes common in both dataset
# 1: PRDX4 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.209470, 0.00330125
# 2: SEC22B gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.164718, 0.0245387
# 3: RPL17 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.154184, 0.0460219
# 4: SNHG1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.184118, 0.020852
# 5: B2M gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.319433, 9.67097e-08
# 6: VMP1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.237980, 0.000325236
# 7: RPS26 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.224259, 0.000701692
# 8: SNHG5 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.228477, 0.000547347
# 9: SNORD102 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.187937, 0.0397974
# 10: LINC00493 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.147763, 0.0714877
# 11: SUMO2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.149461, 0.0527521
# 12: PRDX3 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.283091, 3.69162e-06
# 13: PLIN2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.179091, 0.027352
# 14: NME7 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.205896, 0.00423529
# 15: C19orf53 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.159043, 0.0443578
# 16: SHISA2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.178211, 0.0519773
# 17: C5orf15 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.179731, 0.095365
# 18: RIN2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.148041, 0.0571487
# 19: ARPC2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.184335, 0.00766606
# 20: TXNL1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.144504, 0.0928536
# 21: AKR1B1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.300556, 2.27175e-06
# 22: CISD3 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.666667, 0.0316477
# 23: DDAH1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.226432, 0.000557554
# 24: SDHD gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.253922, 7.7422e-05
# 25: PTMA gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.160572, 0.0285962
# 26: RPS15 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.237321, 0.000227984
# 27: LDHA gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.261365, 2.25345e-05
# 28: PSMB4 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.157168, 0.0290262
# 29: RPS29 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.357403, 2.59147e-09
# 30: ECI2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.180350, 0.0114689
# 31: SRSF3 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.206215, 0.00146082
# 32: RPS7 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.208586, 0.00157592
# 33: RPLP0 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.149737, 0.0433985
# 34: MDH2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0
 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.250910, 0.00168745
# 254: CCT5 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.196898, 0.00323728
# 255: COPS5 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.201561, 0.0111674
# 256: COX4I1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.147398, 0.0643436
# 257: RPL36AL gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.283871, 5.15278e-06
# 258: S100A11 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.138757, 0.0890303
# 259: POLR2L gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.286666, 3.83613e-06
# 260: PSMC4 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.180703, 0.016452
# 261: UBA1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.243640, 0.0487819
# 262: RPS27L gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.187519, 0.00870351
# 263: VPS25 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.152102, 0.0813693
# 264: C3orf14 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.243467, 0.0013167
# 265: AUP1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.202998, 0.0328569
# 266: MT2A gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.250801, 7.17817e-05
# 267: GSTP1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.212255, 0.00128147
# 268: DTWD1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.352371, 0.0341401
# 269: GABARAP gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.201282, 0.00336672
# 270: GPN1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.156590, 0.0691786
# 271: LSM3 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.218021, 0.00108568
# 272: ATOX1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.227273, 0.000551151
# 273: H3F3B gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.136791, 0.097939
# 274: TMSB10 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.142012, 0.0599811
# 275: RPL14 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.184783, 0.00760057
# 276: SH3BGRL3 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.190278, 0.00494759
# 277: RFC4 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.167033, 0.0814566
# 278: SRP14 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.194056, 0.00488996
# 279: ITGB1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.215260, 0.00111589
# 280: STMN1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.142337, 0.0621813
# 281: SAR1A gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.141204, 0.0733721
# 282: SLC35F2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.145245, 0.0659681
# 283: EIF3E gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.168986, 0.018381
# 284: FAM216A gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.283926, 0.0198921
# 285: RPS13 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.183150, 0.00797109
# 286: TNFRSF12A gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.190476, 0.0700158
# 287: RPL29 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.154321, 0.037663
# 288: MRPL18 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.152865, 0.0891026
# 289: TRA2A gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.287415, 2.79993e-06
# 290: CINP gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.221984, 0.00802185
# 291: OSTC gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.175285, 0.0150437
# 292: RPL18 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.214700, 0.00121569
# 293: PPP1CB gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.277384, 4.39466e-06
# 294: NDUFB5 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.170860, 0.026565
# 295: TXNRD1 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.220201, 0.00100994
# 296: MAP1B gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.208652, 0.00209822
# 297: PSMA3 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.151619, 0.0499033
# 298: NPC2 gene is differently expressed in baseline and metformin treated cells
# Test Statistics 0.223342, 0.00076812
# 298  with alpha = 0.1
# 225  with alpha = 0.05
# 180  with alpha = 0.025
# 129  with alpha = 0.01
# 104  with alpha = 0.005
# 63  with alpha = 0.001

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axs =plt.subplots(figsize=(10,5))
collabel=("alpha","0.1", "0.05", "0.025","0.01","0.005","0.001")
axs.axis('off')
the_table = axs.table(cellText=[["Number",298,225,180,129,104,63]],colLabels=collabel,loc='center')
plt.show()

# %% [markdown]
# Bayseioan
# Guassian modeling
# KMean Clustering
# 6
# GMN and Kmean

# %% [markdown]
# ## Task 2

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.mixture import GaussianMixture
from scipy import stats
import random
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

import seaborn as sns
# %matplotlib notebook
sns.set_style('whitegrid')

rpkmThreshold = 32
numBaselineClustGMM = 2
numMetforminClustGMM = 3
from sklearn.mixture import GaussianMixture
from scipy import stats
import random
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

import seaborn as sns
# %matplotlib notebook
sns.set_style('whitegrid')

rpkmThreshold = 32
numBaselineClustGMM = 2
numMetforminClustGMM = 3

# %% [markdown]
# ### 1. Extract your RPKM matrix from each dataset. This is simply the dataframe without the first few columns that contain metadata.

# %%
pf = pd.read_csv("task2.txt")
bbc =  baseline_csv.iloc[:, 5:]
mmc = metformin_csv.iloc[:,5:]

# %% [markdown]
# ### 2.Find the transpose of each matrix. This will be the input to your clustering algorithms.

# %%
# transpose
bc = bbc.transpose()
mc = mmc.transpose()

# %% [markdown]
# ### 3. For each transposed matrix:
# #### 1. Apply the Gaussian Mixture Model (GMM) clustering algorithm.
# Since your input is the transposed matrix, you will be clustering by cells.
# #### 2. Use N=2 clusters for the baseline matrix and N=3 clusters for the metformin matrix.
# #### 3. The output of your clustering algorithm is stored in the ‘means_’ attribute.
# REPORT What do these means represent?
#
# REPORT How many cells do you have in each of the 5 clusters?

# %%
# rpkmThreshold = 32
from collections import Counter

numBaselineClustGMM = 2
numMetforminClustGMM = 3
# Use N=2 clusters
gmm_b = GaussianMixture(n_components=numBaselineClustGMM, random_state=0).fit(bc)
gmm_pred_b = gmm_b.predict(bc)
centers_b = gmm_b.means_


numMetforminClustGMM = 3
# Use N=3 clusters
gmm_m = GaussianMixture(n_components=numMetforminClustGMM, random_state=0).fit(mc)
gmm_pred_m = gmm_m.predict(mc)
centers_m = gmm_m.means_
print("gmm_means is mean parameters for each mixture component")

# How many cells 
pred_b = Counter(gmm_pred_b)
pred_m = Counter(gmm_pred_m)
pred_b = sorted((pred_b.most_common()))
pred_m = sorted((pred_m.most_common()))
print("Below is how many cells are in each cluster \n", pred_b,'\n', pred_m)
# Out:
# gmm_means is mean parameters for each mixture component
# Below is how many cells are in each cluster
#  [(0, 152), (1, 17)]
#  [(0, 161), (1, 11), (2, 5)]

# %% [markdown]
# ### Code combined with 5
#
# ### 4.Using the results of your clustering algorithm, create new mean baseline and mean metformin datasets
#
# #### 1.Preserve metadata from the original dataframes
# #### 2.Store the means of each cluster in additional columns
# An example for the baseline dataset has been provided:
#
# ### 5. For your mean datasets,
# Define clusters Bu and Bv such that |Bu|<|Bv| where |B| represents the number of cells in cluster B in the baseline dataset.
# (i.e let Bu represent the smaller cluster and Bv represent the larger one)
# Similarly, define clusters Mx, My and Mz such that |Mx|<|My|<|Mz| where |M| represents the number of cells in cluster M in the metformin dataset.

# %%
baselineCells = gmm_b
df_baseline_means = baseline_csv.iloc[:, 0:5]  # preserve metadata from first 5 columns
df_baseline_means["Bu"] = baselineCells.means_[1]
df_baseline_means["Bv"] = baselineCells.means_[0] 

metforminCells = gmm_m
df_metformin_means = metformin_csv.iloc[:, 0:5]  # preserve metadata from first 5 columns
df_metformin_means["Mx"] = metforminCells.means_[2]
df_metformin_means["My"] = metforminCells.means_[1]
df_metformin_means["Mz"] = metforminCells.means_[0]

# %% [markdown]
# ### 6.Filter your mean metformin dataset to only include genes that meet the following condition
# Mx¯¯¯¯¯¯¯<rpkmThreshold<My¯¯¯¯¯¯¯ and rpkmThreshold<Mz¯¯¯¯¯¯¯ where M¯¯¯¯¯ represents the mean of cluster M.
# Call this new dataframe metformin_upMy_downMx_upMz_DF.
# Hint: Cluster means are in the dataframe you created in Step 4. However, the order of your means may change with each run of the clustering algorithm. Hence, you will have to identify how to map columns “1”, “2” and “3” to Mx¯¯¯¯¯¯¯,My¯¯¯¯¯¯¯ and Mz¯¯¯¯¯¯¯. You might want to pick a fixed random state for your clustering algorithm to ensure the ordering is always the same.

# %%
metformin_upMy_downMx_upMz_DF = df_metformin_means.loc[(df_metformin_means['Mx'] < 32)&(32 < df_metformin_means['My'])&(32< df_metformin_means['Mz'])]
print(len(metformin_upMy_downMx_upMz_DF))
(metformin_upMy_downMx_upMz_DF).head()
# Out:
# 338
#     Chr   GeneID      Start       Stop  CodingLength   Mx          My  \
# 2  chr1  APOA1BP  156561558  156564091          1121  0.0   78.297295
# 4  chr1    ARPC5  183595332  183604985          1982  0.0  191.115200
# 5  chr1   ATP5F1  111991743  112004525          2101  0.0   51.638597
# 6  chr1  ATP6V0B   44440602   44443972          1022  0.0   35.752469
# 7  chr1    BCAS2  115110181  115124265          1301  0.0   55.242566
#
#            Mz
# 2   34.144335
# 4  132.848917
# 5  206.844776
# 6  129.101251
# 7   91.392282

# %% [markdown]
# ### 7.Similarly, filter your mean baseline dataset to only include genes that meet the following condition
# Bu¯¯¯¯¯¯<rpkmThreshold<Bv¯¯¯¯¯¯ where B¯¯¯¯ represents the mean of cluster B.
# Call this new dataframe baseline_upBv_downBu_DF.
# Hint: Cluster means are in the dataframe you created in Step 4. However, the order of your means may change with each run of the clustering algorithm. Hence, you will have to identify how to map columns “1”, “2” to Bu¯¯¯¯¯¯ and Bv¯¯¯¯¯¯. You might want to pick a fixed random state for your clustering algorithm to ensure the ordering is always the same.

# %%
baseline_upBv_downBu_DF = df_baseline_means.loc[(df_baseline_means['Bu'] < 32)&(32 < df_baseline_means['Bv'])]
print(len(baseline_upBv_downBu_DF))
(baseline_upBv_downBu_DF).head()
# Out:
# 82
#      Chr  GeneID  StartCoding       Stop  CodingLength        Bu          Bv
# 13  chr1   C4BPB    207262212  207273337          1195   0.00000   79.371928
# 36  chr1    GNG5     84964006   84972262           806   0.00000  231.590817
# 42  chr1    ILF2    153634514  153643479          1612  30.71635  175.105702
# 43  chr1   ISG15       948847     949919           666   0.00000   42.883895
# 55  chr1  MRPS21    150266269  150280819           939   0.00000   42.406040

# %% [markdown]
# ### 8. Are they any genes common in your filtered datasets from steps 6 & 7?
# Low expression level genes in Mx may come from Bu. These are genes with an inherently low expression level.
# To account for inherently low expression levels, remove any genes that exist in baseline_upBv_downBu_DF from metformin_upMy_downMx_upMz_DF.
# Call this filtered dataset newlyDownregulatedGenes_inMx_fromBu_df.

# %%
newlyDownregulatedGenes_inMx_fromBu_df =metformin_upMy_downMx_upMz_DF.loc[(~(metformin_upMy_downMx_upMz_DF["GeneID"]).isin(baseline_upBv_downBu_DF["GeneID"]))] # & df1.user_id.isin(df2.user_id)
print(len(newlyDownregulatedGenes_inMx_fromBu_df))
newlyDownregulatedGenes_inMx_fromBu_df.head()
# Out:
# 303
#     Chr   GeneID      Start       Stop  CodingLength   Mx          My  \
# 2  chr1  APOA1BP  156561558  156564091          1121  0.0   78.297295
# 4  chr1    ARPC5  183595332  183604985          1982  0.0  191.115200
# 5  chr1   ATP5F1  111991743  112004525          2101  0.0   51.638597
# 6  chr1  ATP6V0B   44440602   44443972          1022  0.0   35.752469
# 7  chr1    BCAS2  115110181  115124265          1301  0.0   55.242566
#
#            Mz
# 2   34.144335
# 4  132.848917
# 5  206.844776
# 6  129.101251
# 7   91.392282

# %% [markdown]
# ### 9.Find genes that are common to newlyDownregulatedGenes_inMx_fromBu_df and your mean baseline dataset.
# Further filter your mean baseline and mean metformin dataframes to include only these overlap genes.
#
# Your dataframes will now contain only downregulated genes.

# %%
n = newlyDownregulatedGenes_inMx_fromBu_df
b = baseline_upBv_downBu_DF
db = df_baseline_means
dm = df_metformin_means
n = newlyDownregulatedGenes_inMx_fromBu_df

n_b_common = set(db['GeneID'].tolist()).intersection(set(n['GeneID'].tolist()))
print("%d genes common in both dataset newlyDownregulatedGenes_inMx_fromBu_df and df_baseline_means" % len(n_b_common))
# Out:
# 221 genes common in both dataset newlyDownregulatedGenes_inMx_fromBu_df and df_baseline_means

# %%
down_metformin = df_metformin_means.loc[df_metformin_means["GeneID"].isin(n_b_common)]
down_baseline = df_baseline_means.loc[df_baseline_means["GeneID"].isin(n_b_common)]
len(down_metformin)                             
len(down_baseline)                             
down_metformin = down_metformin.reset_index(drop=True)
down_baseline = down_baseline.reset_index(drop=True)
down_baseline.head()
# Out:
#     Chr   GeneID  StartCoding       Stop  CodingLength          Bu          Bv
# 0  chr1    ARPC5    183595332  183604985          1982   51.795593  106.269814
# 1  chr1   ATP5F1    111991743  112004525          2101   71.062689  214.599276
# 2  chr1  ATP6V0B     44440602   44443972          1022  198.217053  163.116030
# 3  chr1  C1orf31    234509214  234519795           856   48.910375   88.970780
# 4  chr1    CDC20     43824626   43828873          1674  159.940069   93.770963

# %% [markdown]
# ### 10.Create a new dataframe with the following data:
# A column containing Bu¯¯¯¯¯¯for downregulated genes.
#
# A column containing Bv¯¯¯¯¯¯for downregulated genes.
#
# A column containing My¯¯¯¯¯¯¯for downregulated genes.
#
# A column containing Mz¯¯¯¯¯¯¯for downregulated genes.
# You should have 4 columns with approx 230 genes/rows/entries.

# %%
dataframe = pd.DataFrame()
dataframe["Bu"] = down_baseline['Bu']
dataframe["Bv"] = down_baseline['Bv']
dataframe["My"] = down_metformin['My']
dataframe["Mz"] = down_metformin['Mz']

# %% [markdown]
# ### 11.Next, apply the log + 1 transformation to your dataframe in Step 10.
# As long as your dataframe consists of all floats, this can be achieved by
#
#   		new_df = np.log(df + 1)
#
#
# Then, find the row means and row standard deviation for each row in your new dataframe.
# Hint: Use np.mean/np.std or dataframe.apply to create new columns containing means and standard deviations

# %%
new_dataframe = np.log(dataframe+1)
new_dataframe["mean"] = new_dataframe.mean(axis=1)
new_dataframe["std"] = new_dataframe.std(axis=1)
new_dataframe.head()
# Out:
#          Bu        Bv        My        Mz      mean       std
# 0  3.966428  4.675347  5.258095  4.896712  4.699145  0.471407
# 1  4.277536  5.373421  3.963450  5.336792  4.737800  0.627349
# 2  5.294395  5.100574  3.604205  4.868313  4.716872  0.659871
# 3  3.910229  4.499485  4.939882  4.543935  4.473383  0.367567
# 4  5.081032  4.551463  6.026550  4.457334  5.029095  0.623028

# %% [markdown]
# ### 12.Finally, add a column containing Mx¯¯¯¯¯¯¯ for downregulated genes to your dataframe in Step 11.
# Apply the log+1 transformation to this column as well.

# %%
new_dataframe["Mx"] = down_metformin['Mx']
new_dataframe["Mx"] = np.log(new_dataframe["Mx"]+1)
new_dataframe.head()
# Out:
#          Bu        Bv        My        Mz      mean       std   Mx
# 0  3.966428  4.675347  5.258095  4.896712  4.699145  0.471407  0.0
# 1  4.277536  5.373421  3.963450  5.336792  4.737800  0.627349  0.0
# 2  5.294395  5.100574  3.604205  4.868313  4.716872  0.659871  0.0
# 3  3.910229  4.499485  4.939882  4.543935  4.473383  0.367567  0.0
# 4  5.081032  4.551463  6.026550  4.457334  5.029095  0.623028  0.0

# %% [markdown]
# ### 13.Visualize each cluster by providing a box plot. You will have 5 boxes, one each for Bu,Bv,Mx,My and Mz.
# One of your clusters should have zero expression.

# %%
fig = plt.figure(figsize=(10, 10)) 
new_dataframe.boxplot(column = ['Bu', 'Bv', 'Mx', 'My', 'Mz'], fontsize = 20)
plt.show()

# %% [markdown]
# ### 14. Repeat Tasks 1-13 with k-means clustering in Step 3.
#
# #### 1. Perform silhouette analysis to pick the optimal value of k (number of clusters).
# Provide the silhouette score or line plot for each value of k
#
# #### 2. Are you able to replicate the results obtained with GMM clustering? For filtering with more than 2 or 3 clusters, filter the smallest cluster such that Mx<rpkmThreshold<otherMs
# or Bu<rpkmThreshold<otherBs.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
def do_kmeans(matrix, num_clusters):
    cluster = KMeans(n_clusters=num_clusters, random_state=0).fit(matrix)
    kmeans_pred = cluster.predict(matrix)
    return silhouette_score(matrix, kmeans_pred)

# %%
N = [i for i in range (2, 20)]
scores = [do_kmeans(bc, i) for i in N]

for i in range(0, len(N)):
    print("For n={}, score={:.3f}".format(N[i], scores[i]))
# Out:
# For n=2, score=0.919
# For n=3, score=0.879
# For n=4, score=0.873
# For n=5, score=0.839
# For n=6, score=0.840
# For n=7, score=0.827
# For n=8, score=0.829
# For n=9, score=0.225
# For n=10, score=0.841
# For n=11, score=0.825
# For n=12, score=0.235
# For n=13, score=0.199
# For n=14, score=0.210
# For n=15, score=0.202
# For n=16, score=0.204
# For n=17, score=0.201
# For n=18, score=0.210
# For n=19, score=0.209

# %%
f, ax = plt.subplots(1)
xdata = N
ydata = scores
ax.plot(xdata, ydata)
ax.set_xlim(xmin=2)
plt.show(f)

# %%
N = [i for i in range (2, 20)]
scores_m = [do_kmeans(mc, i) for i in N]

for i in range(0, len(N)):
    print("For n={}, score={:.3f}".format(N[i], scores_m[i]))
# Out:
# For n=2, score=0.913
# For n=3, score=0.893
# For n=4, score=0.836
# For n=5, score=0.826
# For n=6, score=0.255
# For n=7, score=0.251
# For n=8, score=0.247
# For n=9, score=0.248
# For n=10, score=0.246
# For n=11, score=0.244
# For n=12, score=0.244
# For n=13, score=0.242
# For n=14, score=0.234
# For n=15, score=0.187
# For n=16, score=0.243
# For n=17, score=0.138
# For n=18, score=0.163
# For n=19, score=0.169

# %%
f, ax = plt.subplots(1)
xdata = N
ydata = scores_m
ax.plot(xdata, ydata)
ax.set_xlim(xmin=2)
plt.show(f)

# %%
print("From the plot and the data, we find that when both dataset has two clusters, the silhouette scores are the highest ")
# Out:
# From the plot and the data, we find that when both dataset has two clusters, the silhouette scores are the highest

# %% [markdown]
# ### Recommand cluster size with (2,2)

# %%
kb =2
km =2
cluster_b = KMeans(n_clusters=kb, random_state=0).fit(bc)
kmeans_pred_b = cluster_b.predict(bc)
kmeans_centers_b = cluster_b.cluster_centers_


cluster_m = KMeans(n_clusters=km, random_state=0).fit(mc)
kmeans_pred_m = cluster_m.predict(mc)
kmeans_centers_m = cluster_m.cluster_centers_

# %% [markdown]
# ### find each cluster counts

# %%
k_pred_b = Counter(kmeans_pred_b)
k_pred_m = Counter(kmeans_pred_m)
k_pred_b = sorted((k_pred_b.most_common()))
k_pred_m = sorted((k_pred_m.most_common()))
print("Below is how many cells are in each cluster \n", k_pred_b,'\n', k_pred_m)
# Out:
# Below is how many cells are in each cluster
#  [(0, 152), (1, 17)]
#  [(0, 161), (1, 16)]

# %% [markdown]
# ### Assign with Bu Bv Mx My

# %%
baselineCells_k = kmeans_centers_b
df_baseline_means_k = baseline_csv.iloc[:, 0:5]  # preserve metadata from first 5 columns
df_baseline_means_k["Bu"] = baselineCells_k[1]
df_baseline_means_k["Bv"] = baselineCells_k[0] 

metforminCells_k = kmeans_centers_m
df_metformin_means_k = metformin_csv.iloc[:, 0:5]  # preserve metadata from first 5 columns
df_metformin_means_k["Mx"] = metforminCells_k[1]
df_metformin_means_k["My"] = metforminCells_k[0]

# df_baseline_means_k 
# df_metformin_means_k

# %% [markdown]
# ### filter data

# %%
metformin_upMy_downMx_upMz_DF = df_metformin_means_k.loc[(df_metformin_means_k['Mx'] < 32)&(32 < df_metformin_means_k['My'])]
len(metformin_upMy_downMx_upMz_DF)
baseline_upBv_downBu_DF = df_baseline_means_k.loc[(df_baseline_means_k['Bu'] < 32)&(32 < df_baseline_means_k['Bv'])]

newlyDownregulatedGenes_inMx_fromBu_df =metformin_upMy_downMx_upMz_DF.loc[(~(metformin_upMy_downMx_upMz_DF["GeneID"]).isin(baseline_upBv_downBu_DF["GeneID"]))] # & df1.user_id.isin(df2.user_id)

n = newlyDownregulatedGenes_inMx_fromBu_df
db = df_baseline_means_k
dm = df_metformin_means_k

n_b_common = set(db['GeneID'].tolist()).intersection(set(n['GeneID'].tolist()))
print("%d genes common in both dataset newlyDownregulatedGenes_inMx_fromBu_df and df_baseline_means_k" % len(n_b_common))


down_metformin = df_metformin_means_k.loc[df_metformin_means_k["GeneID"].isin(n_b_common)]
down_baseline = df_baseline_means_k.loc[df_baseline_means_k["GeneID"].isin(n_b_common)]
len(down_metformin)                             
len(down_baseline)                             
down_metformin = down_metformin.reset_index(drop=True)
down_baseline = down_baseline.reset_index(drop=True)
down_baseline.head()
# Out:
# 35 genes common in both dataset newlyDownregulatedGenes_inMx_fromBu_df and df_baseline_means_k
#     Chr   GeneID  StartCoding       Stop  CodingLength          Bu          Bv
# 0  chr1  ATP6V0B     44440602   44443972          1022  198.217053  163.116030
# 1  chr1     G0S2    209848670  209849735           963  213.206365   60.178957
# 2  chr1  KRTCAP2    155141884  155145804           547  162.813694  109.969308
# 3  chr1    UBE2T    202300785  202311094           908  174.152156  133.492286
# 4  chr1     UFC1    161123534  161128646          1122  124.259126   71.514477

# %% [markdown]
# ### New dataframe contains Bu Bv My Mx

# %%
dataframe = pd.DataFrame()
dataframe["Bu"] = down_baseline['Bu']
dataframe["Bv"] = down_baseline['Bv']
dataframe["Mx"] = down_metformin['Mx']
dataframe["My"] = down_metformin['My']

nnew_dataframe = np.log(dataframe+1)
nnew_dataframe["mean"] = new_dataframe.mean(axis=1)
nnew_dataframe["std"] = new_dataframe.std(axis=1)
fig = plt.figure(figsize=(10, 10)) 
nnew_dataframe.boxplot(column = ['Bu', 'Bv', 'Mx', 'My'], fontsize = 20)
# df = pd.DataFrame(columns=['Bu', 'Bv', 'Mx', 'My', 'Mz'])
# df.plot.box()
plt.show()
# new_dataframe

# %% [markdown]
# ## Task 3 - Principal Component Analysis
#
# #### Perform Princial Component Analysis on your datasets.
# How many components did you use for your analysis?
#
# Provide a cumulative variance expression or knee curve to justify your answer.
#
# Provide a visualization of your analysis. Remember to include eigenvectors of the covariance matrix.
#
# Your datapoint labels will originate from your GMM clustering predictions. You should have one biplot for baseline with 2 clusters and another for metformin with 3 clusters.

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

from sklearn import datasets
from sklearn.decomposition import PCA
from IPython.display import Image

# %%
baseline_csv = pd.read_csv("498DS_BaselineData.csv")
metformin_csv = pd.read_csv("498DS_MetforminData.csv")
# metforminT = metformin_csv.transpose()
baseline = baseline_csv.drop(['Chr','GeneID','StartCoding','Stop','CodingLength'], axis=1)
metformin= metformin_csv.drop(['Chr','GeneID','Stop','Start','CodingLength'], axis=1)
baselineT = baseline.transpose()
metforminT= metformin.transpose()

# %% [markdown]
# # A Summary of the PCA Approach
# * Standardize the data.
# * Obtain the Eigenvectors and Eigenvalues from the covariance matrix or correlation matrix, or perform Singular Vector Decomposition.
# * Sort eigenvalues in descending order and choose the $k$ eigenvectors that correspond to the $k$ largest eigenvalues where $k$ is the number of dimensions of the new feature subspace ($k \leq d$).
# * Construct the projection matrix $W$ from the selected $k$ eigenvectors.
# * Transform the original dataset $X$ via $W$ to obtain a $k$-dimensional feature subspace $Y$.

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Step 2 - Eigendecomposition
#
# The eigenvectors and eigenvalues of a covariance (or correlation) matrix represent the “core” of a PCA: The eigenvectors (principal components) determine the directions of the new feature space, and the eigenvalues determine their magnitude. In other words, the eigenvalues explain the variance of the data along the new feature axes.
#
# The classic approach to PCA is to perform the eigendecomposition on the covariance matrix $\Sigma$, which is a
# $d \times d$ matrix where each element represents the covariance between two features. The covariance between two features is calculated as follows:
#
# $$\sigma_{jk} = \frac{1}{n-1} (X - \overline{x})^T (X - \overline{x})$$
#
# where $\overline{x}$ is the mean vector, $\frac{1}{n} \sum_{i=i}^{n} x_i$
#
# The mean vector is a $d$-dimensional vector where each value in this vector represents the sample mean of a feature column in the dataset.
#
# ### We'll use the covariance matrix approach, but you could also use the correlation matrix or perform Singular Vector Decomposition

# %%
mean_vec_m = np.mean(metforminT, axis=0) # by column
cov_matr_m = (metforminT - mean_vec_m).T.dot((metforminT - mean_vec_m)) / (metforminT.shape[0] - 1)
# print(cov_matr)
cov_matr_m = np.cov(metforminT.T)
eig_vals_m, eig_vecs_m = np.linalg.eig(cov_matr_m)

# %%
mean_vec_b = np.mean(baselineT, axis=0) # by column
cov_matr_b = (baselineT - mean_vec_b).T.dot((baselineT - mean_vec_b)) / (baselineT.shape[0] - 1)
# print(cov_matr)
# mean_vec_cell = np.mean(metforminT, axis=0) # by column
# cov_matr = (metforminT - mean_vec_cell).T.dot((metforminT - mean_vec_cell)) / (baselineT.shape[0] - 1)
# print(cov_matr)
# metforminT
cov_matr_b = np.cov(baselineT.T)
eig_vals_b, eig_vecs_b = np.linalg.eig(cov_matr_b)

# %%
print(eig_vals_m)
print(eig_vals_b)
# Out:
# [  3.46232104e+09 +0.00000000e+00j   2.75048752e+07 +0.00000000e+00j
#    2.44462207e+07 +0.00000000e+00j ...,   1.80408338e-12 +3.17276134e-13j
#    1.80408338e-12 -3.17276134e-13j   1.41189811e-12 +0.00000000e+00j]
# [  4.25583026e+09+0.j   5.40361445e+07+0.j   1.72011776e+07+0.j ...,
#   -7.24491101e-13+0.j  -7.89333422e-13+0.j  -1.80502593e-12+0.j]

# %%
print(eig_vecs_m.T)
print(eig_vals_b.T)
# Out:
# [[  3.43661812e-04 +0.00000000e+00j  -1.15280167e-03 +0.00000000e+00j
#     5.41971353e-05 +0.00000000e+00j ...,   2.08306564e-03 +0.00000000e+00j
#     3.35038615e-04 +0.00000000e+00j   2.06159835e-04 +0.00000000e+00j]
#  [ -4.05553708e-04 +0.00000000e+00j   2.63463862e-03 +0.00000000e+00j
#     1.72691551e-03 +0.00000000e+00j ...,   2.89854610e-03 +0.00000000e+00j
#     3.32135257e-03 +0.00000000e+00j  -9.73168769e-03 +0.00000000e+00j]
#  [ -1.95509129e-03 +0.00000000e+00j  -5.80389307e-03 +0.00000000e+00j
#    -1.06479851e-03 +0.00000000e+00j ...,   6.58627393e-04 +0.00000000e+00j
#    -1.93989417e-03 +0.00000000e+00j   6.30688422e-04 +0.00000000e+00j]
#  ...,
#  [  2.21477287e-03 -2.32022489e-03j  -2.27590094e-05 +8.64258480e-06j
#    -1.47128106e-04 +3.20716411e-05j ...,   3.07276568e-04 +7.40659640e-04j
#    -3.02191397e-03 +9.92252888e-03j   2.33110698e-01 +0.00000000e+00j]
#  [  2.21477287e-03 +2.32022489e-03j  -2.27590094e-05 -8.64258480e-06j
#    -1.47128106e-04 -3.20716411e-05j ...,   3.07276568e-04 -7.40659640e-04j
#    -3.02191397e-03 -9.92252888e-03j   2.33110698e-01 -0.00000000e+00j]
#  [ -4.58020919e-03 +0.00000000e+00j   1.52561483e-05 +0.00000000e+00j
#     1.71482946e-04 +0.00000000e+00j ...,  -4.36176879e-03 +0.00000000e+00j
#     1.03204604e-02 +0.00000000e+00j  -2.33035672e-01 +0.00000000e+00j]]
# [  4.25583026e+09+0.j   5.40361445e+07+0.j   1.72011776e+07+0.j ...,
#   -7.24491101e-13+0.j  -7.89333422e-13+0.j  -1.80502593e-12+0.j]

# %% [markdown]
# ## Step 3 - Selecting Principal Components
#
# In order to decide which eigenvector(s) can dropped without losing too much information for the construction of lower-dimensional subspace, we need to inspect the corresponding eigenvalues: The eigenvectors with the lowest eigenvalues bear the least information about the distribution of the data; those are the ones can be dropped.
# In order to do so, the common approach is to rank the eigenvalues from highest to lowest in order choose the top $k$
# eigenvectors.

# %%
eig_pairs_m = [(np.abs(eig_vals_m[i]), eig_vecs_m[:,i]) for i in range(len(eig_vals_m))]
eig_pairs_m.sort(key=lambda x: x[0], reverse=True)

eig_pairs_b = [(np.abs(eig_vals_b[i]), eig_vecs_b[:,i]) for i in range(len(eig_vals_b))]
eig_pairs_b.sort(key=lambda x: x[0], reverse=True)

# %%
print('Eigenvalues in descending order:')
for i in eig_pairs_b:
    print(i[0],": ",i[1])
    
print('Eigenvalues in descending order:')
for i in eig_pairs_m:
    print(i[0],": ",i[1])
# Out:
# Eigenvalues in descending order:
# 4255830263.15 :  [-0.00025519+0.j  0.00104352+0.j  0.00024425+0.j ...,  0.00041346+0.j
#  -0.00038282+0.j -0.00144758+0.j]
# 54036144.5209 :  [ 0.00218542+0.j  0.00031892+0.j -0.00295964+0.j ...,  0.00279250+0.j
#  -0.01214673+0.j  0.00280927+0.j]
# 17201177.6084 :  [-0.00375811+0.j -0.00384839+0.j  0.00115170+0.j ..., -0.00645662+0.j
#   0.06745663+0.j  0.01405424+0.j]
# 15719158.4154 :  [ 0.00238210+0.j -0.00247529+0.j  0.00245324+0.j ...,  0.00580086+0.j
#   0.01649187+0.j -0.00229119+0.j]
# 10681140.2223 :  [  2.03622757e-05+0.j  -1.58639856e-02+0.j   1.29013378e-03+0.j ...,
#   -7.18830196e-03+0.j  -6.58076177e-02+0.j   2.64825824e-03+0.j]
# 9779146.22368 :  [-0.00136538+0.j -0.01447524+0.j  0.00297202+0.j ..., -0.00827449+0.j
#   0.00403028+0.j  0.00299177+0.j]
# 5814003.94749 :  [ 0.00297528+0.j  0.00045869+0.j  0.00770182+0.j ..., -0.01385558+0.j
#   0.07208351+0.j  0.00177711+0.j]
# 5493454.73672 :  [-0.01429914+0.j  0.00970960+0.j -0.00027468+0.j ...,  0.01017610+0.j
#   0.00767768+0.j -0.00367256+0.j]
# 4297355.8575 :  [-0.00466801+0.j  0.02016114+0.j -0.00747653+0.j ...,  0.01888964+0.j
#   0.11042044+0.j  0.00632916+0.j]
# 3660857.11048 :  [-0.00911486+0.j  0.00782656+0.j -0.00078954+0.j ...,  0.00096868+0.j
#   0.04093511+0.j -0.00576034+0.j]
# 3338390.79844 :  [-0.00404356+0.j  0.02856408+0.j  0.00283457+0.j ...,  0.01751756+0.j
#   0.04432962+0.j  0.01567850+0.j]
# 3311349.52655 :  [-0.00188388+0.j  0.01339794+0.j -0.00071050+0.j ..., -0.01231559+0.j
#   0.09667954+0.j -0.00522977+0.j]
#   -4.66362327e-02 +1.14151131e-02j  -4.90297525e-04 -1.75158257e-02j]
# 1.01656978053e-12 :  [  2.25722229e-04 +3.17534085e-04j   6.10015052e-05 -2.87939092e-05j
#   -2.25235621e-04 -8.83752970e-06j ...,  -4.26769592e-02 +3.80071841e-02j
#   -3.81660723e-02 +2.30137790e-02j   1.53928522e-02 -1.94186666e-03j]
# 1.01656978053e-12 :  [  2.25722229e-04 -3.17534085e-04j   6.10015052e-05 +2.87939092e-05j
#   -2.25235621e-04 +8.83752970e-06j ...,  -4.26769592e-02 -3.80071841e-02j
#   -3.81660723e-02 -2.30137790e-02j   1.53928522e-02 +1.94186666e-03j]
# 4.13918611925e-13 :  [  4.05082889e-03+0.j  -4.32205348e-05+0.j  -7.53934778e-05+0.j ...,
#    7.63290180e-03+0.j  -1.16946616e-02+0.j  -6.45531285e-02+0.j]
# 4.10582923861e-13 :  [ -4.83720374e-04 +1.49648700e-03j  -2.58302243e-05 -3.18817070e-05j
#    6.35945246e-05 -1.05110319e-05j ...,   1.99472323e-02 -1.09786331e-02j
#    2.82814898e-02 +9.26014106e-03j  -3.95875809e-02 +2.61183494e-03j]
# 4.10582923861e-13 :  [ -4.83720374e-04 -1.49648700e-03j  -2.58302243e-05 +3.18817070e-05j
#    6.35945246e-05 +1.05110319e-05j ...,   1.99472323e-02 +1.09786331e-02j
#    2.82814898e-02 -9.26014106e-03j  -3.95875809e-02 -2.61183494e-03j]

# %% [markdown]
# ### Explained Variance
# After sorting the eigenpairs, the next question is “how many principal components are we going to choose for our new feature subspace?” A useful measure is the so-called “explained variance,” which can be calculated from the eigenvalues. The explained variance tells us how much information (variance) can be attributed to each of the principal components.

# %%
total_b = sum(eig_vals_b)
var_exp_b = [(i / total_b)*100 for i in sorted(eig_vals_b, reverse=True)]
cum_var_exp_b = np.cumsum(var_exp_b)
cum_var_exp_b

total_m = sum(eig_vals_m)
var_exp_m = [(i / total_m)*100 for i in sorted(eig_vals_m, reverse=True)]
cum_var_exp_m = np.cumsum(var_exp_m)
cum_var_exp_m
# Out:
# array([ 96.57536730 +0.00000000e+00j,  97.34256751 +0.00000000e+00j,
#         98.02445192 +0.00000000e+00j, ..., 100.00000000 +0.00000000e+00j,
#        100.00000000 +9.52230375e-17j, 100.00000000 +0.00000000e+00j])

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(1170), var_exp_b, alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(1170), cum_var_exp_b, where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Yaxin\Anaconda3\lib\site-packages\matplotlib\transforms.py:814: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\Yaxin\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(1170), var_exp_m, alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(1170), cum_var_exp_m, where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Yaxin\Anaconda3\lib\site-packages\matplotlib\transforms.py:814: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\Yaxin\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(3), var_exp_b[:3], alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(3), cum_var_exp_b[:3], where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Yaxin\Anaconda3\lib\site-packages\matplotlib\transforms.py:814: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\Yaxin\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(3), var_exp_m[:3], alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(3), cum_var_exp_m[:3], where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Yaxin\Anaconda3\lib\site-packages\matplotlib\transforms.py:814: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# C:\Users\Yaxin\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# The plot above clearly shows that most of the variance (97% of the variance to be precise) can be explained by the first principal component alone. The second principal component still bears some information (1%) while the third and fourth principal components can safely be dropped without losing to much information. Together, the first two principal components contain 98% of the information.

# %% [markdown]
# ## Step 4 - Projection Matrix
# The construction of the projection matrix that will be used to transform the data onto the new feature subspace. Although, the name “projection matrix” has a nice ring to it, it is basically just a matrix of our concatenated top k eigenvectors.
#
#
# Here, we are reducing the 1170-dimensional feature space to a 2-dimensional feature subspace, by choosing the “top 2” eigenvectors with the highest eigenvalues to construct our $d \times k$-dimensional eigenvector matrix $W$.

# %%
matrix_w_b = np.hstack((eig_pairs_b[0][1].reshape(1170,1),
                      eig_pairs_b[1][1].reshape(1170,1)))
print(matrix_w_b)

matrix_w_m = np.hstack((eig_pairs_m[0][1].reshape(1170,1),
                      eig_pairs_m[1][1].reshape(1170,1),eig_pairs_m[2][1].reshape(1170,1)))
print(matrix_w_m)
# Out:
# [[-0.00025519+0.j  0.00218542+0.j]
#  [ 0.00104352+0.j  0.00031892+0.j]
#  [ 0.00024425+0.j -0.00295964+0.j]
#  ...,
#  [ 0.00041346+0.j  0.00279250+0.j]
#  [-0.00038282+0.j -0.01214673+0.j]
#  [-0.00144758+0.j  0.00280927+0.j]]
# [[  3.43661812e-04+0.j  -4.05553708e-04+0.j  -1.95509129e-03+0.j]
#  [ -1.15280167e-03+0.j   2.63463862e-03+0.j  -5.80389307e-03+0.j]
#  [  5.41971353e-05+0.j   1.72691551e-03+0.j  -1.06479851e-03+0.j]
#  ...,
#  [  2.08306564e-03+0.j   2.89854610e-03+0.j   6.58627393e-04+0.j]
#  [  3.35038615e-04+0.j   3.32135257e-03+0.j  -1.93989417e-03+0.j]
#  [  2.06159835e-04+0.j  -9.73168769e-03+0.j   6.30688422e-04+0.j]]

# %% [markdown]
# ## Step 5 - Projecting onto the new feature space
#
# In this last step we will use the $1170\times2$-dimensional projection matrix $W$ to transform our samples onto the new subspace via the equation
# $$Y=X\times W$$
# , where $Y$ is a $169/177\times 2$ matrix of our transformed samples.

# %%
# print(len(Y))
# Y
bT = baselineT.values
Y_b = bT.dot(matrix_w_b)
Y_b[:,0] = -Y_b[:,0]
Y_b[:,1] = -Y_b[:,1]

Y_m = metforminT.dot(matrix_w_m)
len(Y_m)
# Out:
# 177

# %% [markdown]
# Now, what we have after applying the linear PCA transformation is a lower dimensional subspace (from 4D to 2D in this case), where the samples are “most spread” along the new feature axes.

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(12, 10))
    for i,(lab, col) in enumerate(zip(('b1', 'b2'),
                        ('blue','red'))):
        plt.scatter(Y_b[gmm_pred_b == i, 0],
                    Y_b[gmm_pred_b == i, 1],
                    label=lab,
                    c=col)
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend(loc='lower center')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Yaxin\Anaconda3\lib\site-packages\numpy\core\numeric.py:583: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(12,10))
    for i,(la, co) in enumerate(zip(('m1', 'm2','m3'),
                        ('red', 'green','blue'))):
        plt.scatter(Y_m.values[gmm_pred_m== i, 0],
                    Y_m.values[gmm_pred_m== i, 1],
                    label=la,
                    c=co)
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend(loc='lower center')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Yaxin\Anaconda3\lib\site-packages\numpy\core\numeric.py:583: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
# with plt.style.context('seaborn-whitegrid'):
#     plt.figure(figsize=(12,10))
#     for i,(la, co) in enumerate(zip(('m1', 'm2','m3'),
#                         ('red', 'green','blue'))):
#         plt.scatter(Y_m.values[gmm_pred_m== i, 0],
#                     Y_m.values[gmm_pred_m== i, 1],
#                     label=la,
#                     c=co)
#     plt.xlabel('Principal Component 1')
#     plt.ylabel('Principal Component 2')
# #     plt.xlim( (-50, 50) )  # set the ylim to ymin, ymax
# #     plt.ylim(-3000,30000 )    # set the ylim to ymin, ymax
#     plt.legend(loc='lower center')
#     plt.tight_layout()
#     plt.show()

# %%
ba = baseline_csv.drop(['Chr','StartCoding','Stop','CodingLength'], axis=1)
me = metformin_csv.drop(['Chr','Stop','Start','CodingLength'], axis=1)
gene_ba = list(baseline_csv['GeneID'])
gene_me = list(metformin_csv['GeneID'])

# %%
from sklearn.decomposition import PCA as sklearnPCA
sklearn_pca = sklearnPCA(n_components=2)
Y_sklearn = sklearn_pca.fit_transform(baselineT)

# 0,1 denote PC1 and PC2; change values for other PCs
xvector = sklearn_pca.components_[0] 
yvector = sklearn_pca.components_[1]

xs = sklearn_pca.transform(baselineT)[:,0] 
ys = sklearn_pca.transform(baselineT)[:,1]




with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(12, 8))
    for i, lab, col in zip((0,1),('b1', 'b2'),
                        ('blue', 'red')):
        plt.scatter(Y_sklearn[gmm_pred_b==i, 0],
                    Y_sklearn[gmm_pred_b==i, 1],
                    label=lab,
                    c=col)
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend(loc='lower right')
    plt.tight_layout()
    
    
    for i in range(len(xvector)):
# arrows project features (ie columns from csv) as vectors onto PC axes
        plt.arrow(0, 0, xvector[i]*max(xs), yvector[i]*max(ys),
              color='r', width=0.0005, head_width=0.0025)
    
        plt.text(xvector[i]*max(xs)*1.2, yvector[i]*max(ys)*1.2,
             list(gene_ba)[i], color='black',fontsize =20)
    
    plt.show()

# %%
print(xvector)
print(yvector)
# baselineTeig_pairs_b[0]
# eig_pairs_b[1]

# %%
from sklearn.decomposition import PCA as sklearnPCA
sklearn_pcaa = sklearnPCA(n_components=2)
Y_sklearnn = sklearn_pcaa.fit_transform(metforminT)
Y_sklearnn[:,1] = -Y_sklearnn[:,1] 
# 0,1 denote PC1 and PC2; change values for other PCs
xvectorr = sklearn_pcaa.components_[0] 
yvectorr = -sklearn_pcaa.components_[1]

xss = sklearn_pcaa.transform(metforminT)[:,0] 
yss = -sklearn_pcaa.transform(metforminT)[:,1]

# %%
print(xvectorr)
xvector
# Out:
# [  3.43661812e-04  -1.15280167e-03   5.41971353e-05 ...,   2.08306564e-03
#    3.35038615e-04   2.06159835e-04]
# array([ 0.00025519, -0.00104352, -0.00024425, ..., -0.00041346,
#         0.00038282,  0.00144758])

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(12,8))
    for i,(la, co) in enumerate(zip(('m1', 'm2','m3'),
                        ('red', 'green','blue'))):
        plt.scatter(Y_sklearnn[gmm_pred_m== i, 0],
                    Y_sklearnn[gmm_pred_m== i, 1],
                    label=la,
                    c=co)
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend(loc='lower center')
    plt.tight_layout()
    
    
    for i in range(len(xvectorr)):
# arrows project features (ie columns from csv) as vectors onto PC axes
        plt.arrow(0, 0, xvectorr[i]*max(xss), yvectorr[i]*max(yss),
              color='r', width=0.0005, head_width=0.0025)
    
        plt.text(xvectorr[i]*max(xss)*1.2, yvectorr[i]*max(yss)*1.2,
             list(gene_me)[i], color='black',fontsize = 20)
    
    plt.show()

# %%
baseline_csv.loc[baseline_csv['GeneID'] == 'MRPS7']
baseline_csv.loc[baseline_csv['GeneID'] == 'RPL18A']

# %%
metformin_csv
